# %%
from google.colab import drive
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns
drive.mount('/content/drive')

f = '/content/drive/My Drive/provaf.csv'

df = pd.read_csv(f)
print(df.shape)
print(df.columns)

# %%
df = df[['tot_filtri', 'Spatial_distibution']].reset_index(drop=True)

# %%
df['Spatial_distibution'].str.replace('unified ', 'unified')
df['Spatial_distibution'].str.replace('distributed compact ', 'distributed compact')
df['Spatial_distibution'].str.replace('distributed ', 'distributed')
# Out:
# 0                 unified
# 1             distributed
# 2      distributedcompact
# 3             distributed
# 4             distributed
#               ...
# 975                   NaN
# 976                   NaN
# 977               unified
# 978               unified
# 979                   NaN
# Name: Spatial_distibution, Length: 980, dtype: object

# %%
dff=df.dropna().reset_index(drop=True)

# %%
# %matplotlib inline
df1 = df['tot_filtri']
bp = plt.boxplot(df1)
plt.show()

# %%
bp.keys()
for key in bp:
    print(f'{key}: {[item.get_ydata() for item in bp[key]]}\n')
# Out:
# whiskers: [array([2., 0.]), array([10., 22.])]
#
# caps: [array([0, 0]), array([22, 22])]
#
# boxes: [array([ 2.,  2., 10., 10.,  2.])]
#
# medians: [array([5., 5.])]
#
# fliers: [array([51, 33, 26, 39, 40, 27, 30, 29, 24, 26, 34, 35, 28, 24, 24, 45, 25,
#        53, 28, 25, 23, 41, 24, 24, 38, 24, 29, 35, 29, 56, 53, 24, 27, 35,
#        24, 23, 24, 27, 24, 30, 62, 24, 50, 33, 30, 30, 40])]
#
# means: []

# %%
df7 = df
df7 = len(df[(df["tot_filtri"]>=0) & (df["Spatial_distibution"]=="unified") & (df["tot_filtri"]< 2)])
print(f'pochi filtri - unificati: {df7}')
# Out:
# pochi filtri - unificati: 57

# %%
df8 = df
df8 = len(df[(df["tot_filtri"]>=0) & (df["Spatial_distibution"]=="distributed") & (df["tot_filtri"]< 2)])
print(f'pochi filtri - distribuiti: {df8}')
# Out:
# pochi filtri - distribuiti: 0

# %%
df88 = df
df88 = len(df[(df["tot_filtri"]>=0) & (df["Spatial_distibution"]=="distributed compact") & (df["tot_filtri"]< 2)])
print(f'pochi filtri - distribuiti compact: {df88}')
# Out:
# pochi filtri - distribuiti compact: 0

# %%
df9 = df
df9 = len(df[(df["tot_filtri"]>=2) & (df["Spatial_distibution"]=="unified") & (df["tot_filtri"]<= 10)])
print(f'media filtri - unificati: {df9}')
# Out:
# media filtri - unificati: 350

# %%
df10 = df
df10 = len(df[(df["tot_filtri"]>=2) & (df["Spatial_distibution"]=="distributed") & (df["tot_filtri"]<= 10)])
print(f'media filtri - distribuiti: {df10}')
# Out:
# media filtri - distribuiti: 137

# %%
df100 = df
df100 = len(df[(df["tot_filtri"]>=2) & (df["Spatial_distibution"]=="distributed compact") & (df["tot_filtri"]<= 10)])
print(f'media filtri - distribuiti compact: {df100}')
# Out:
# media filtri - distribuiti compact: 62

# %%
df11 = df
df11 = len(df[(df["tot_filtri"]>10) & (df["Spatial_distibution"]=="unified") & (df["tot_filtri"]<= 22)])
print(f'tanti filtri - unificati: {df11}')
# Out:
# tanti filtri - unificati: 88

# %%
df12 = df
df12 = len(df[(df["tot_filtri"]>10) & (df["Spatial_distibution"]=="distributed") & (df["tot_filtri"]<= 22)])
print(f'tanti filtri - distribuiti: {df12}')
# Out:
# tanti filtri - distribuiti: 52

# %%
df122 = df
df122 = len(df[(df["tot_filtri"]>10) & (df["Spatial_distibution"]=="distributed compact") & (df["tot_filtri"]<= 22)])
print(f'tanti filtri - distribuiti compact: {df122}')
# Out:
# tanti filtri - distribuiti compact: 57

# %% [markdown]
# **box diviso in parti uguali**

# %%
df13 = df
df13 = len(df[(df["tot_filtri"]>=2) & (df["Spatial_distibution"]=="unified") & (df["tot_filtri"]<= 4)])
print(f'primo box - unificati: {df13}')
# Out:
# primo box - unificati: 154

# %%
df14 = df
df14 = len(df[(df["tot_filtri"]>=2) & (df["Spatial_distibution"]=="distributed") & (df["tot_filtri"]<= 4)])
print(f'primo box - distribuiti: {df14}')
# Out:
# primo box - distribuiti: 58

# %%
df14 = df
df14 = len(df[(df["tot_filtri"]>=2) & (df["Spatial_distibution"]=="distributed compact") & (df["tot_filtri"]<= 4)])
print(f'primo box - distribuiti compact: {df14}')
# Out:
# primo box - distribuiti compact: 6

# %%
df15 = df
df15 = len(df[(df["tot_filtri"]>=5) & (df["Spatial_distibution"]=="unified") & (df["tot_filtri"]<= 7)])
print(f'secondo box - unificati: {df15}')
# Out:
# secondo box - unificati: 123

# %%
df16 = df
df16 = len(df[(df["tot_filtri"]>=5) & (df["Spatial_distibution"]=="distributed") & (df["tot_filtri"]<= 7)])
print(f'secondo box - distribuiti: {df16}')
# Out:
# secondo box - distribuiti: 45

# %%
df17 = df
df17 = len(df[(df["tot_filtri"]>=5) & (df["Spatial_distibution"]=="distributed compact") & (df["tot_filtri"]<= 7)])
print(f'secondo box - distribuiti compact: {df17}')
# Out:
# secondo box - distribuiti compact: 35

# %%
df18 = df
df18 = len(df[(df["tot_filtri"]>=8) & (df["Spatial_distibution"]=="unified") & (df["tot_filtri"]<= 10)])
print(f'terzo box - unificati: {df18}')
# Out:
# terzo box - unificati: 73

# %%
df19 = df
df19 = len(df[(df["tot_filtri"]>=8) & (df["Spatial_distibution"]=="distributed") & (df["tot_filtri"]<= 10)])
print(f'terzo box - distributed: {df19}')
# Out:
# terzo box - distributed: 34

# %%
df20 = df
df20 = len(df[(df["tot_filtri"]>=8) & (df["Spatial_distibution"]=="distributed compact") & (df["tot_filtri"]<= 10)])
print(f'terzo box - distributed compact: {df20}')
# Out:
# terzo box - distributed compact: 21

# %% [markdown]
# **secondo box centrato sulla mediana**

# %%
df131 = df
df131 = len(df[(df["tot_filtri"]>=2) & (df["Spatial_distibution"]=="unified") & (df["tot_filtri"]<= 3)])
print(f'primo box - unificati: {df131}')
# Out:
# primo box - unificati: 118

# %%
df132 = df
df132 = len(df[(df["tot_filtri"]>=2) & (df["Spatial_distibution"]=="distributed") & (df["tot_filtri"]<= 3)])
print(f'primo box - distribuiti: {df132}')
# Out:
# primo box - distribuiti: 39

# %%
df133 = df
df133 = len(df[(df["tot_filtri"]>=2) & (df["Spatial_distibution"]=="distributed compact") & (df["tot_filtri"]<= 3)])
print(f'primo box - distribuiti compact: {df133}')
# Out:
# primo box - distribuiti compact: 3

# %%
df141 = df
df141 = len(df[(df["tot_filtri"]>=4) & (df["Spatial_distibution"]=="unified") & (df["tot_filtri"]<= 6)])
print(f'secondo box - unificati: {df141}')
# Out:
# secondo box - unificati: 120

# %%
df142 = df
df142 = len(df[(df["tot_filtri"]>=4) & (df["Spatial_distibution"]=="distributed") & (df["tot_filtri"]<= 6)])
print(f'secondo box - distribuiti: {df142}')
# Out:
# secondo box - distribuiti: 51

# %%
df143 = df
df143 = len(df[(df["tot_filtri"]>=4) & (df["Spatial_distibution"]=="distributed compact") & (df["tot_filtri"]<=6)])
print(f'secondo box - distribuiti compact: {df143}')
# Out:
# secondo box - distribuiti compact: 26

# %%
df151 = df
df151 = len(df[(df["tot_filtri"]>= 7) & (df["Spatial_distibution"]=="unified") & (df["tot_filtri"]<= 10)])
print(f'terzo box - unificati: {df151}')
# Out:
# terzo box - unificati: 112

# %%
df152 = df
df152 = len(df[(df["tot_filtri"]>=7) & (df["Spatial_distibution"]=="distributed") & (df["tot_filtri"]<= 10)])
print(f'terzo box - distribuiti: {df152}')
# Out:
# terzo box - distribuiti: 47

# %%
df153 = df
df153 = len(df[(df["tot_filtri"]>= 7) & (df["Spatial_distibution"]=="distributed compact") & (df["tot_filtri"]<= 10)])
print(f'terzo box - distribuiti compact: {df153}')
# Out:
# terzo box - distribuiti compact: 33
